# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# Load the CSV file with separate latitude and longitude columns
df = pd.read_csv("../data/sex_work_arrests.csv")

# Create a 'geometry' column with Point objects
df['geometry'] = df.apply(lambda row: Point(row['Longitude'], row['Latitude']), axis=1)

# Convert the DataFrame to a GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry='geometry')

# Set the coordinate reference system (CRS)
gdf.set_crs("EPSG:4326", inplace=True)

# # Export to GeoJSON
# gdf.to_file("../data/coords.geojson", driver="GeoJSON")
# Out:
#        ARREST_KEY  ARREST_YEAR                         PD_DESC    LAW_CODE  \
# 0       293983828         2024  PROSTITUTION, PATRONIZING 4, 3  PL 2300400
# 1       293597451         2024  PROSTITUTION, PATRONIZING 4, 3  PL 2300400
# 2       293597456         2024  PROSTITUTION, PATRONIZING 4, 3  PL 2300400
# 3       293597453         2024  PROSTITUTION, PATRONIZING 4, 3  PL 2300400
# 4       293531851         2024                    PROSTITUTION  PL 2300000
# ...           ...          ...                             ...         ...
# 38286     9933087         2006                    PROSTITUTION  PL 2300000
# 38287     9933235         2006         PROSTITUTION,PERMITTING  PL 2304000
# 38288     9933237         2006                    PROSTITUTION  PL 2300000
# 38289     9933084         2006                    PROSTITUTION  PL 2300000
# 38290     9933088         2006                    PROSTITUTION  PL 2300000
#
# ...

# %%
import pandas as pd
import geopandas as gpd


gdf = gpd.GeoDataFrame(df, geometry='geometry')
duplicates = gdf['geometry'].value_counts()
print(duplicates)
# Out:
# geometry
# POINT (-73.79786 40.698)      524
# POINT (-73.88868 40.74714)    520
# POINT (-73.91981 40.68822)    490
# POINT (-73.88579 40.74745)    475
# POINT (-73.89887 40.86559)    374
#                              ...
# POINT (-73.9872 40.69439)       1
# POINT (-73.89282 40.74275)      1
# POINT (-73.96453 40.80207)      1
# POINT (-73.81307 40.70063)      1
# POINT (-74.01317 40.6441)       1
# Name: count, Length: 6103, dtype: int64
