# %% [markdown]
# # Pull Data Using API
# ```$limit allows you to pull more than the max default that opendata sets```

# %% [markdown]
# ```Uncomment & Execute API to Updated/Redownload Data```

# %%
import pandas as pd
# rest of the code remains the same

# Check that the request was successful
    # Read the content of the response with pandas
df = pd.read_csv("/Users/davidpaiz-torres/dataProjects/coding_the_news/dashboard_project/datasets/2024_violations.csv")
df
# Out:
#           CAMIS                        DBA       BORO BUILDING  \
# 0      50017749              KINGS KITCHEN  Manhattan       92
# 1      50079419                    GRACE'S  Manhattan      252
# 2      50145538               BEST WOK NO1   Brooklyn    3411A
# 3      50134992              YU XIANG YUAN     Queens    14238
# 4      50103414                       ACRE   Brooklyn       64
# ...         ...                        ...        ...      ...
# 17085  50016354          THE EMPANADA SPOT     Queens     8417
# 17086  41304936                  DRAM SHOP   Brooklyn      339
# 17087  50121663                 TAL BAGELS  Manhattan     2446
# 17088  41250519               MILANO'S BAR  Manhattan       51
# 17089  41280104  NO 1 LUCK SUNG RESTAURANT      Bronx      694
#
#                     STREET  ZIPCODE CUISINE DESCRIPTION INSPECTION DATE  \
# 0            EAST BROADWAY  10002.0             Chinese      01/09/2024
# ...

# %% [markdown]
# # Check that all rows of data are here

# %%
len(df)
# Out:
# 17090

# %%
df.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE', 'Latitude', 'Longitude',
#        'Community Board', 'Council District', 'Census Tract', 'BIN', 'BBL',
#        'NTA'],
#       dtype='object')

# %% [markdown]
# # Set  a Variable With Certain Columns

# %% [markdown]
# # Call New List

# %%
sorted_df = df.sort_values(by="INSPECTION DATE", ascending=False)
sorted_df.head()
# Out:
#           CAMIS               DBA      BORO BUILDING         STREET  ZIPCODE  \
# 13087  50066640  FISHERMAN'S COVE  Brooklyn     4917  CHURCH AVENUE  11203.0
# 2229   50066640  FISHERMAN'S COVE  Brooklyn     4917  CHURCH AVENUE  11203.0
# 6933   50066640  FISHERMAN'S COVE  Brooklyn     4917  CHURCH AVENUE  11203.0
# 539    50066640  FISHERMAN'S COVE  Brooklyn     4917  CHURCH AVENUE  11203.0
# 16985  50066640  FISHERMAN'S COVE  Brooklyn     4917  CHURCH AVENUE  11203.0
#
#       CUISINE DESCRIPTION INSPECTION DATE  \
# 13087           Caribbean      03/15/2024
# 2229            Caribbean      03/15/2024
# 6933            Caribbean      03/15/2024
# 539             Caribbean      03/15/2024
# 16985           Caribbean      03/15/2024
#
#                                                 ACTION VIOLATION CODE  ...  \
# 13087  Violations were cited in the following area(s).            02B  ...
# 2229   Violations were cited in the following area(s).            08C  ...
# ...

# %%
boro_counts = df[['BORO']].value_counts().head().to_frame('Borough Counts')
boro_counts
# Out:
#                Borough Counts
# BORO
# Manhattan                6001
# Brooklyn                 5032
# Queens                   3721
# Bronx                    1556
# Staten Island             780

# %%
# Make sure all the data is there
boro_counts.sum()
# Out:
# Borough Counts    17090
# dtype: int64

# %%
# Check unique values of each row (onoly 2 violation codes, because I filtered it to only show rat/mice related violations via google sheets)
df.nunique()
# Out:
# CAMIS                    4481
# DBA                      3830
# BORO                        5
# BUILDING                 2544
# STREET                   1074
# ZIPCODE                   185
# CUISINE DESCRIPTION        76
# INSPECTION DATE            54
# ACTION                      5
# VIOLATION CODE             90
# VIOLATION DESCRIPTION      99
# CRITICAL FLAG               3
# SCORE                      94
# GRADE                       6
# GRADE DATE                 53
# RECORD DATE                 1
# INSPECTION TYPE            28
# Latitude                 4239
# Longitude                4241
# Community Board            61
# Council District           51
# Census Tract              907
# BIN                      4056
# BBL                      4068
# NTA                       190
# dtype: int64

# %%
biz_counts = pd.read_csv("/Users/davidpaiz-torres/dataProjects/coding_the_news/dashboard_project/datasets//breakdowns_by_res.csv")

# %% [markdown]
# # Get the counts for each Restuarant

# %% [markdown]
# ```Re-run if data has been updated```

# %%
columns = ['BORO']
if all(col in df.columns for col in columns):
    res_counts = df[columns].value_counts().head().to_frame("res_counts").sort_values(by="res_counts", ascending=False)
res_counts
# Out:
#                res_counts
# BORO
# Manhattan            6001
# Brooklyn             5032
# Queens               3721
# Bronx                1556
# Staten Island         780

# %%
columns = ['BORO']
if all(col in df.columns for col in columns):
    res_counts = df[columns].value_counts().head().to_frame("res_counts").sort_values(by="res_counts", ascending=False)
res_counts
# Out:
#                res_counts
# BORO
# Manhattan            6001
# Brooklyn             5032
# Queens               3721
# Bronx                1556
# Staten Island         780

# %%
columns = ['DBA']
if all(col in df.columns for col in columns):
    res_counts = df[columns].value_counts().head().to_frame("DBA_COUNT").sort_values(by="DBA", ascending=False)
res_counts
# Out:
#                        DBA_COUNT
# DBA
# SUBWAY                       155
# STARBUCKS                     74
# MCDONALD'S                   137
# KENNEDY FRIED CHICKEN         66
# DUNKIN                       215

# %% [markdown]
# # Get the counts for each Violation Code

# %% [markdown]
# ```Re-run if data has been updated```

# %%
df['VIOLATION CODE'].value_counts() #
# Out:
# VIOLATION CODE
# 10F      2457
# 08A      1480
# 10B      1165
# 06C      1075
# 06D      1038
#          ...
# 19-08       1
# 06H         1
# 04I         1
# 02D         1
# 19-01       1
# Name: count, Length: 90, dtype: int64

# %%
# percent_sentence = print(f"Violations where evidence of mice or life mice in an establishment make up nearly 4% of all violations")
# percent_sentence

# %% [markdown]
# # Get the counts for each Community Board

# %% [markdown]
# ```Re-run if data has been updated```

# %% [markdown]
# # Define Community Board by 100s:
# ```Manhattan = 100```
# ```Bronx = 200```
# ```Brooklyn = 300```
# ```Queens = 400```
# ```Staten Island = 500```

# %%
df["VIOLATION DESCRIPTION"].unique()
# Out:
# array(['Hot TCS food item not held at or above 140 °F.',
#        "Evidence of mice or live mice in establishment's food or non-food areas.",
#        'Food Protection Certificate (FPC) not held by manager or supervisor of food operations.',
#        nan, "Live roaches in facility's food or non-food area.",
#        'Thawing procedure improper.',
#        'Wash hands sign not posted near or above hand washing sink.',
#        "Evidence of rats or live rats in establishment's food or non-food areas.",
#        'Accurate thermometer not provided or properly located in refrigerated, cold storage or hot holding equipment',
#        'Lighting fixture located over, by or within food storage, preparation, service or display facility, and facility where utensils and equipment are cleaned and stored, which may shatter due to extreme heat, temperature changes or accidental contact; not fitted with shatterproof bulb or shielded and encased, with end caps or other device.',
# ...

# %%
df["DBA"].value_counts().head(10)
# Out:
# DBA
# DUNKIN                                   215
# SUBWAY                                   155
# MCDONALD'S                               137
# STARBUCKS                                 74
# KENNEDY FRIED CHICKEN                     66
# POPEYES                                   54
# BURGER KING                               48
# GOLDEN KRUST CARIBBEAN BAKERY & GRILL     47
# DUNKIN DONUTS                             40
# PARIS BAGUETTE                            40
# Name: count, dtype: int64

# %%
df[df["VIOLATION CODE"] == "04L"][["BORO", "DBA"]].value_counts().sort_values(ascending=False)
# Out:
# BORO           DBA
# Queens         SUBWAY                               5
# Manhattan      BLUESTONE LANE                       4
# Bronx          KENNEDY FRIED CHICKEN                3
# Manhattan      CRUMBL                               3
# Bronx          DUNKIN                               3
#                                                    ..
#                ANISE                                1
# Staten Island  ROSEBANK PIZZA                       1
# Bronx          ANDY'S TERIYAKI & TACO               1
#                ADAYA AFRICAN AMERICAN RESTAURANT    1
# Staten Island  WILD CRAB HOUSE                      1
# Name: count, Length: 941, dtype: int64
